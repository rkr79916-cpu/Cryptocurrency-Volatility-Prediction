# %%
README
# Crypto Volatility Prediction

## Objective
Predict cryptocurrency volatility using ML.

## Models Used
- Random Forest

## Features
- OHLC
- Moving averages
- Volatility metrics

## Results
- RMSE: <your score>

## Run
streamlit run app.py
