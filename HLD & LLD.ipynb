# %% [markdown]
# #HLD (High-Level Design)
# User → Streamlit UI → Model API → Prediction Output
#
#                 ↓
#         Preprocessing Pipeline
#                 ↓
#           Feature Engineering
#                 ↓
#              ML Model

# %% [markdown]
# #LLD (Low-Level Design)
#
# Modules:
#
# * preprocess.py → cleaning & scaling
# * feature_engineering.py → indicators
# * train.py → training
# * predict.py → inference
# * app.py → UI
